# %% [markdown]
# <a href="https://colab.research.google.com/github/PavelStelmakhV/hw305-scipy/blob/main/Hw5.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.optimize import minimize_scalar

from scipy.optimize import minimize
import numpy as np
import matplotlib.pyplot as plt

from scipy.interpolate import griddata

# %%
x = np.linspace(-10, 10, 10000)
y = np.linspace(-10, 10, 10000)
X, Y = np.meshgrid(x, y)

px, py = np.random.choice(x, 2500), np.random.choice(y, 2500)

def paraboloid(arg):
    x, y = arg
    return x ** 2  + y ** 2

z = griddata((px, py), paraboloid((px, py)), (X, Y), method='cubic')
plt.contour(x, y, z)

# %%
minimize(paraboloid, [1, 5])
# Out:
#   message: Optimization terminated successfully.
#   success: True
#    status: 0
#       fun: 3.0912486424497277e-13
#         x: [-5.234e-07  1.877e-07]
#       nit: 3
#       jac: [-1.032e-06  3.903e-07]
#  hess_inv: [[ 9.808e-01 -9.615e-02]
#             [-9.615e-02  5.192e-01]]
#      nfev: 12
#      njev: 4
