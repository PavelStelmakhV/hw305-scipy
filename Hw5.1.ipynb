# %% [markdown]
# <a href="https://colab.research.google.com/github/PavelStelmakhV/hw305-scipy/blob/main/Hw5.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.optimize import minimize
import numpy as np
import matplotlib.pyplot as plt

S = 1000

# %%
x_ = np.linspace(1, 300, 300)
y_ = 2 * x_ + 1000 / x_
plt.grid()
plt.plot(x_, y_)
plt.xlabel('сторона "a"')
plt.ylabel('длина ограды')
plt.ylim(0, 600)
plt.show()

# %%
def fence_length(x):
  return 2 * x[0] + x[1]

# %%
x0 = np.array([1, 1])
cons = ({'type': 'eq', 'fun': lambda x:  x[0] * x[1] - S},)
bounds=((1, None), (1, None))
result = minimize(fence_length, x0,  method='trust-constr', bounds=bounds, constraints=cons)
print(f'Минимальная длина ограды - {result.fun} со сторонами {result.x[0]} x {result.x[1]} x {result.x[0]}')
# Out:
# Минимальная длина ограды - 89.44271909999159 со сторонами 22.360679750230194 x 44.7213595995312 x 22.360679750230194
